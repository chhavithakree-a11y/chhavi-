# %% [markdown]
# <a href="https://colab.research.google.com/github/chhavithakree-a11y/chhavi-/blob/main/2.Phython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# check whether 15 is greater than 10?

# %%
15 > 10
# Out:
# True

# %% [markdown]
# check whether 5 is less than 20?

# %%
5 < 20
# Out:
# True

# %% [markdown]
# check whether 10 is equal to 10.

# %%
10 == 10
# Out:
# True

# %% [markdown]
# check whether 25 is not equal to 30

# %%
25 != 30
# Out:
# True

# %% [markdown]
# check whether 50 is greater than or equals to 40.

# %%
50 >= 40
# Out:
# True

# %% [markdown]
# check whether 30 is less than or equals to 30.

# %%
30 <= 30
# Out:
# True

# %% [markdown]
# create a variable age=20 and check whether the age is greater than or equals to 18

# %%
age = 20
age = 18
20 >= 18
# Out:
# True

# %% [markdown]
# create  a variable marks = 35 and check whether marks are greater than or equals to 40.

# %%
marks = 35
marks = 40
35 >= 40
# Out:
# False

# %% [markdown]
# create two variables.

# %%
a = 10
b = 20
10 < 20
# Out:
# True

# %% [markdown]
# create :

# %%
x = 50
50 == 50
# Out:
# True

# %% [markdown]
# create two variables: num1 = 100 and num2 = 50 check whether the num1 is greater than num2.

# %%
num1 = 100
num2 = 50
100 > 50
# Out:
# True

# %% [markdown]
# check whether the string 'apple' is equals to string 'apple'.

# %%
'apple' == 'apple'
# Out:
# True

# %% [markdown]
# create a variable current_temp = 20 and check whether the current_temp is not equals to 25.

# %%
current_temp = 20
20 != 25
# Out:
# True

# %% [markdown]
# check wheather 7 is less than or equals to 7

# %%
7 <= 7
# Out:
# True

# %% [markdown]
# create a variable score = 95. check wheater score is greater than 90.

# %%
score = 95
score= 90
95 > 90
# Out:
# True

# %% [markdown]
# create a variable is_raining = true. check wheater is_raining is equals to false.

# %%
is_raining = True
is_raining == False
# Out:
# False

# %% [markdown]
# create a variable item_count = 0. check wheater item_count is less than 1.

# %%
item_count = 0
0 < 1
# Out:
# True

# %% [markdown]
# create a variable price = 20.50 . check wheater price is greater than or equals to 20.

# %%
price = 20.50
20.50 <= 20
# Out:
# False

# %% [markdown]
# create two string variables; city 1= 'London' and city2= 'Paris'. check wheater city1 is not equals to city2.

# %%
city1= 'London'
city2 = 'Paris'
'London' != 'Paris'
# Out:
# True

# %% [markdown]
# create a variable year = 2024. check wheater year is equals to 2024.

# %%
year = 2024
year == 2024
# Out:
# True
